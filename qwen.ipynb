# %% [markdown]
# # Qwen learning notebook (bootstrap)
#
# This repository toolkit cannot directly vendor upstream files automatically in this environment.
# Use the cell below to download the upstream Qwen notebook for study.
#
# Upstream source: https://github.com/QwenLM/Qwen/blob/main/recipes/quickstart/qwen.ipynb

# %%
import pathlib
import urllib.request

url = 'https://raw.githubusercontent.com/QwenLM/Qwen/main/recipes/quickstart/qwen.ipynb'
out = pathlib.Path('qwen_upstream.ipynb')
urllib.request.urlretrieve(url, out)
print(f'Downloaded upstream notebook to: {out.resolve()}')

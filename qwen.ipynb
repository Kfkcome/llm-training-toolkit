# %% [markdown]
# # Qwen quickstart notebook
#
# This notebook is intended to mirror the upstream Qwen quickstart notebook for study.
#
# Upstream source: https://github.com/QwenLM/Qwen/blob/main/recipes/quickstart/qwen.ipynb
#
# Note: I wasn't able to automatically copy the full upstream notebook content via the available GitHub tooling in this environment.
# To get the exact notebook, download it from the link above and replace this file.
